# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot

# %%
dims = (9, 9)

# %%
nonp = pd.read_csv("nonp.csv")
onep = pd.read_csv("onep.csv")
onep = onep.sort_values(by=['senders', 'throughput', 'efficiency'])
onep = onep.round(decimals=4)
nonp = nonp.sort_values(by=['senders', 'throughput', 'efficiency'])
nonp = nonp.round(decimals=4)

# %%
fig,ax = pyplot.subplots(figsize=dims)
#ax.set(yscale="log")
plot = sns.lineplot(ax=ax, x="senders", y="avgFwdDelay", err_style=bar, data=onep)
plot = sns.lineplot(ax=ax, x="senders", y="avgFwdDelay", err_style=None, data=nonp)
ax.grid(True)
plot.figure.savefig("nonp_avgFwdDelayp.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-31974b40c3d5> in <module>
#       1 fig,ax = pyplot.subplots(figsize=dims)
#       2 #ax.set(yscale="log")
# ----> 3 plot = sns.lineplot(ax=ax, x="senders", y="avgFwdDelay", err_style=bar, data=onep)
#       4 plot = sns.lineplot(ax=ax, x="senders", y="avgFwdDelay", err_style=None, data=nonp)
#       5 ax.grid(True)
#
# NameError: name 'bar' is not defined

# %%
concatenated = pd.concat([onep.assign(dataset='onep'), nonp.assign(dataset='nonp')])

# %%
concatenated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 72 to 53
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   senders      180 non-null    int64
#  1   pvalue       180 non-null    int64
#  2   efficiency   180 non-null    float64
#  3   throughput   180 non-null    float64
#  4   avgFwdDelay  180 non-null    int64
#  5   dataset      180 non-null    object
# dtypes: float64(2), int64(3), object(1)
# memory usage: 9.8+ KB

# %%
fig,ax = pyplot.subplots(figsize=dims)
#ax.set(yscale="log")
plot = sns.lineplot(ax=ax, x="senders", y="efficiency", hue="dataset", err_style=None, data=concatenated)
ax.grid(True)
plot.figure.savefig("comp_efficiency.png")
