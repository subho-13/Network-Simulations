# %%
import pandas
import seaborn
from matplotlib import pyplot
import numpy

# %%
df = pandas.read_csv("onep.csv")

# %%
dims = (11.7, 8.27)

# %%
fig,ax = pyplot.subplots(figsize=dims)
ax.set(yscale="log")
mymodel = numpy.poly1d(numpy.polyfit(df['senders'], df[' avgFwdDelay'], 3))
seaborn.regplot(ax=ax, x="senders", y=" avgFwdDelay", 
                        data=df, scatter=False)
# Out:
# <AxesSubplot:xlabel='senders', ylabel=' avgFwdDelay'>

# %%
plotter = df.set_index('senders')

# %%
# Out:
#   File "<ipython-input-64-9658064ce244>", line 1
#     plotter[" efficiency" && ('sender' == 2)].plot.scatter()
#                            ^
# SyntaxError: invalid syntax
